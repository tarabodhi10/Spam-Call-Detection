# %%
#conda  install pyaudio

# %%
# Donot execute----while creating new csv file
import pandas as pd
df=pd.DataFrame(columns={'text','label'})
df

# %%
#only 1st time execute  1
import pandas as pd

df=pd.read_csv('Phishing_Call_Dataset.csv',index_col=0)
# df=pd.read_csv('Phishing_Call_Dataset.csv')
df
# Out:
#                                                  text label
# 0              bank is providing credit card for free   ham
# 1                         ATM is not working properly  spam
# 2                           Can I have your CC number  spam
# 3                           Can I have your DC number  spam
# 4                  Can I have your Credit Card number  spam
# ..                                                ...   ...
# 66  actually I am facing issue for upi transaction...   ham
# 67  hi actually I wanted to do the net banking but...   ham
# 68  hi actually I have forgotten my up M pin can y...   ham
# 69  hi actually I wanted to use mobile banking but...   ham
# 70  actually I tried using forgot password of the ...   ham
#
# [71 rows x 2 columns]

# %%
#import library  2

import speech_recognition as sr

# Initialize recognizer class (for recognizing the speech)

r = sr.Recognizer()

# Reading Microphone as source
# listening the speech and store in audio_text variable

with sr.Microphone() as source:
    print("Talk")
    audio_text = r.listen(source)
    print("Time over, thanks")
print('sss',type(audio_text),audio_text)
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    
try:
    textt=r.recognize_google(audio_text)
    # using google speech recognition
    print("Text: ",textt)
except:
     print("Sorry, I did not get that")
# Out:
# Talk
# Time over, thanks
# sss <class 'speech_recognition.AudioData'> <speech_recognition.AudioData object at 0x000001F9E815FA30>
# Text:  actually I tried using forgot password of the portal but portal is down can you please help me

# %%
df.loc[len(df.index)]=[textt,'ham']

# %%
df.tail()
# Out:
#                                                  text label
# 66  actually I am facing issue for upi transaction...   ham
# 67  hi actually I wanted to do the net banking but...   ham
# 68  hi actually I have forgotten my up M pin can y...   ham
# 69  hi actually I wanted to use mobile banking but...   ham
# 70  actually I tried using forgot password of the ...   ham

# %%
#while saving data in to csv
df.to_csv('Phishing_Call_Dataset.csv')

# %%
len(df.index)
# Out:
# 59

# %%
df
# Out:
#                                                  text label
# 0              bank is providing credit card for free   ham
# 1                         ATM is not working properly  spam
# 2                           Can I have your CC number  spam
# 3                           Can I have your DC number  spam
# 4                  Can I have your Credit Card number  spam
# 5                   Can I have your Debit card number  spam
# 6                    Can you tell your credit details  spam
# 7                Can you tell your debit card details  spam
# 8               Can you tell your credit card details  spam
# 9                Can I have your credit card 16 digit  spam
# 10                Can I have your debit card 16 digit  spam
# 11                Can I have your debit card 16 digit  spam
# 12               Give your credit card details please  spam
# 13                Give your debit card details please  spam
# 14                  Can I have your pin number please  spam
# ...

# %%
df.loc[3]
# Out:
# text     Can I have your DC number
# label                         spam
# Name: 3, dtype: object
